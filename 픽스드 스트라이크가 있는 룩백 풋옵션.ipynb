# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import tensorflow as tf


r = 0.01
sig = 0.2
T = 30/365

M = 2000
N = 60

dt = T/N
rdt = r*dt
sigsdt = sig * np.sqrt(dt)

np.random.seed(1)
S0 = 1
K = 1

S = np.empty([M,N+1])
rv = np.random.normal(r*dt,sigsdt,[M,N])

for i in range(M):
    S[i,0] = S0
    for j in range(N):
        S[i,j+1] = S[i,j] * (1+rv[i,j])

def min_matrix(S):
    minvec_S = np.zeros([M, 1])
    for j in range(M):
        minvec_S[j][0] = np.min(S[j][:])
    return minvec_S
def max_matrix(S):
    maxvec_S = np.zeros([M, 1])
    for j in range(M):
        maxvec_S[j][0] = np.max(S[j][:])
    return maxvec_S

lb_fix_call = np.maximum(np.mean(max_matrix(S) - K), 0) * np.exp(-r*T)
lb_fix_put = np.maximum(np.mean(K - min_matrix(S)), 0) * np.exp(-r*T)
print(lb_fix_call, lb_fix_put)

def delta_model(model_name = None):
    price = tf.keras.layers.Input(shape = (1,))
    
    delta = tf.keras.layers.Dense(32, activation='tanh')(price_set)
    delta = tf.keras.layers.Dense(32, activation='tanh')(price)
    delta = tf.keras.layers.BatchNormalization()(delta)
    delta = tf.keras.layers.Dense(32, activation='tanh')(delta)
    delta = tf.keras.layers.BatchNormalization()(delta)
    delta = tf.keras.layers.Dense(32, activation='tanh')(delta)
    delta = tf.keras.layers.Dense(1, activation='tanh')(delta)

    return tf.keras.Model(inputs=price, outputs=delta, name=model_name)

my_input = []

min_price = tf.keras.layers.Input(shape = (1, ), name = 'min_price')
premium = tf.keras.layers.Input(shape = (1, ), name = "premium")
hedge_cost = tf.keras.layers.Input(shape = (1, ), name = 'hedge_cost')
price = tf.keras.layers.Input(shape = (1, ), name = "price")
price_set = tf.keras.layers.Input(shape = (1, ), name = "price_set")

my_input += [min_price] + [premium] + [hedge_cost] + [price]

for j in range(N):
    delta = delta_model()(price)
    new_price = tf.keras.layers.Input(shape = (1, ), name = 'S_' + str(j + 1))
    my_input = my_input + [new_price]

    price_inc = tf.keras.layers.Subtract(name = 'price_inc_' + str(j))([price, new_price])
    cost = tf.keras.layers.Multiply(name = "stock_" + str(j))([delta, price_inc])
    hedge_cost = tf.keras.layers.Add(name = 'cost_' + str(j))([hedge_cost, cost])
    info_set = tf.keras.layers.Concatenate()([price, new_price])
    price = new_price

payoff = tf.keras.layers.Lambda(lambda x : tf.math.maximum(K - x, 0))(min_price)
cum_cost = tf.keras.layers.Add(name = "hedge_cost_plus_payoff")([hedge_cost, payoff])
cum_cost = tf.keras.layers.Subtract(name = "cum_cost_minus_premium")([cum_cost, premium])

model = tf.keras.Model(inputs = my_input, outputs = cum_cost)

def min_matrix(S):
    minvec_S = np.zeros([M, 1])
    for j in range(M):
        minvec_S[j][0] = np.min(S[j][:])
    return minvec_S

min = min_matrix(S)
min_price = min
premium =lb_fix_put * np.ones([M, 1])
cost = np.zeros([M, 1])
SS = [S[:, i].reshape(M, 1) for i in range(N + 1)]
x = [min_price] + [premium] + [cost] + [SS]
y = np.zeros([M,1])

model.compile(loss='mse', optimizer='adam')

hist = model.fit(x,y, batch_size=32, epochs=50, verbose=True, validation_split=0.2)

plt.plot(hist.history['loss'])
plt.show()
# Out:
# 0.04375600590598895 0.039942257101569206
# Epoch 1/50
# 50/50 [==============================] - 32s 141ms/step - loss: 0.0011 - val_loss: 5.3936e-04
# Epoch 2/50
# 50/50 [==============================] - 3s 67ms/step - loss: 3.4930e-04 - val_loss: 2.8712e-04
# Epoch 3/50
# 50/50 [==============================] - 3s 69ms/step - loss: 1.7993e-04 - val_loss: 2.2963e-04
# Epoch 4/50
# 50/50 [==============================] - 3s 68ms/step - loss: 1.2981e-04 - val_loss: 2.2367e-04
# Epoch 5/50
# 50/50 [==============================] - 3s 68ms/step - loss: 1.1706e-04 - val_loss: 2.3335e-04
# Epoch 6/50
# 50/50 [==============================] - 3s 68ms/step - loss: 1.1660e-04 - val_loss: 2.6687e-04
# Epoch 7/50
# 50/50 [==============================] - 3s 67ms/step - loss: 1.1068e-04 - val_loss: 3.0245e-04
# Epoch 8/50
# 50/50 [==============================] - 3s 67ms/step - loss: 1.0188e-04 - val_loss: 3.2712e-04
# Epoch 9/50
# 50/50 [==============================] - 3s 67ms/step - loss: 1.0452e-04 - val_loss: 4.1556e-04
# Epoch 10/50
# 50/50 [==============================] - 3s 69ms/step - loss: 1.0699e-04 - val_loss: 4.2777e-04
# Epoch 11/50
# 50/50 [==============================] - 3s 69ms/step - loss: 1.0602e-04 - val_loss: 5.1007e-04
# Epoch 12/50
# 50/50 [==============================] - 4s 70ms/step - loss: 9.9263e-05 - val_loss: 5.1675e-04
# Epoch 13/50
# 50/50 [==============================] - 3s 69ms/step - loss: 1.0132e-04 - val_loss: 6.0928e-04
# Epoch 14/50
# 50/50 [==============================] - 3s 69ms/step - loss: 1.0943e-04 - val_loss: 6.3897e-04
# Epoch 15/50
# 50/50 [==============================] - 3s 68ms/step - loss: 1.0632e-04 - val_loss: 5.6171e-04
# Epoch 16/50
# 50/50 [==============================] - 3s 69ms/step - loss: 1.0675e-04 - val_loss: 6.1065e-04
# Epoch 17/50
# 50/50 [==============================] - 3s 70ms/step - loss: 9.9394e-05 - val_loss: 6.7390e-04
# Epoch 18/50
# 50/50 [==============================] - 3s 70ms/step - loss: 1.0547e-04 - val_loss: 5.6666e-04
# Epoch 19/50
# 50/50 [==============================] - 4s 80ms/step - loss: 1.0394e-04 - val_loss: 6.2948e-04
# Epoch 20/50
# 50/50 [==============================] - 4s 70ms/step - loss: 1.0390e-04 - val_loss: 5.7139e-04
# Epoch 21/50
# 50/50 [==============================] - 3s 68ms/step - loss: 1.0167e-04 - val_loss: 5.4903e-04
# Epoch 22/50
# 50/50 [==============================] - 3s 70ms/step - loss: 1.1272e-04 - val_loss: 4.8938e-04
# Epoch 23/50
# 50/50 [==============================] - 3s 69ms/step - loss: 1.0874e-04 - val_loss: 4.2330e-04
# Epoch 24/50
# 50/50 [==============================] - 3s 69ms/step - loss: 1.1196e-04 - val_loss: 4.8889e-04
# Epoch 25/50
# 50/50 [==============================] - 3s 69ms/step - loss: 1.0382e-04 - val_loss: 5.3075e-04
# Epoch 26/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.7863e-05 - val_loss: 4.4156e-04
# Epoch 27/50
# 50/50 [==============================] - 3s 67ms/step - loss: 1.0027e-04 - val_loss: 4.2915e-04
# Epoch 28/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.5389e-05 - val_loss: 3.8159e-04
# Epoch 29/50
# 50/50 [==============================] - 4s 71ms/step - loss: 1.0379e-04 - val_loss: 4.6411e-04
# Epoch 30/50
# 50/50 [==============================] - 3s 68ms/step - loss: 1.0524e-04 - val_loss: 2.8219e-04
# Epoch 31/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.9617e-05 - val_loss: 3.1905e-04
# Epoch 32/50
# 50/50 [==============================] - 3s 69ms/step - loss: 1.0518e-04 - val_loss: 2.5021e-04
# Epoch 33/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.8394e-05 - val_loss: 3.2916e-04
# Epoch 34/50
# 50/50 [==============================] - 3s 68ms/step - loss: 9.7965e-05 - val_loss: 2.7329e-04
# Epoch 35/50
# 50/50 [==============================] - 4s 70ms/step - loss: 9.7733e-05 - val_loss: 3.2855e-04
# Epoch 36/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.8291e-05 - val_loss: 3.6441e-04
# Epoch 37/50
# 50/50 [==============================] - 3s 68ms/step - loss: 9.4763e-05 - val_loss: 3.0655e-04
# Epoch 38/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.2666e-05 - val_loss: 2.2786e-04
# Epoch 39/50
# 50/50 [==============================] - 3s 68ms/step - loss: 9.9748e-05 - val_loss: 3.4419e-04
# Epoch 40/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.4562e-05 - val_loss: 4.1441e-04
# Epoch 41/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.2355e-05 - val_loss: 3.4526e-04
# Epoch 42/50
# 50/50 [==============================] - 3s 70ms/step - loss: 9.7688e-05 - val_loss: 2.8609e-04
# Epoch 43/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.5375e-05 - val_loss: 2.9113e-04
# Epoch 44/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.5208e-05 - val_loss: 3.2193e-04
# Epoch 45/50
# 50/50 [==============================] - 3s 67ms/step - loss: 9.5432e-05 - val_loss: 3.2565e-04
# Epoch 46/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.4642e-05 - val_loss: 3.1589e-04
# Epoch 47/50
# 50/50 [==============================] - 3s 68ms/step - loss: 9.3689e-05 - val_loss: 3.6718e-04
# Epoch 48/50
# 50/50 [==============================] - 3s 69ms/step - loss: 9.2312e-05 - val_loss: 2.8017e-04
# Epoch 49/50
# 50/50 [==============================] - 3s 67ms/step - loss: 9.3078e-05 - val_loss: 2.5949e-04
# Epoch 50/50
# 50/50 [==============================] - 3s 68ms/step - loss: 9.2463e-05 - val_loss: 3.0078e-04

# %%
plt.hist(model.predict(x), bins = 30)
plt.show()
# Out:
# 63/63 [==============================] - 5s 20ms/step

# %%
plt.plot(S[:, -1], model.predict(x), marker = ".", linestyle = 'none')
plt.show()
# Out:
# 63/63 [==============================] - 1s 20ms/step
