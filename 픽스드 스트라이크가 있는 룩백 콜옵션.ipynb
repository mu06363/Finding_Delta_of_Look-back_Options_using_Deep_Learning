# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import tensorflow as tf


r = 0.01
sig = 0.2
T = 30/365

M = 2000
N = 60

dt = T/N
rdt = r*dt
sigsdt = sig * np.sqrt(dt)

np.random.seed(1)
S0 = 1
K = 1

S = np.empty([M,N+1])
rv = np.random.normal(r*dt,sigsdt,[M,N])

for i in range(M):
    S[i,0] = S0
    for j in range(N):
        S[i,j+1] = S[i,j] * (1+rv[i,j])

def min_matrix(S):
    minvec_S = np.zeros([M, 1])
    for j in range(M):
        minvec_S[j][0] = np.min(S[j][:])
    return minvec_S
def max_matrix(S):
    maxvec_S = np.zeros([M, 1])
    for j in range(M):
        maxvec_S[j][0] = np.max(S[j][:])
    return maxvec_S

lb_fix_call = np.maximum(np.mean(max_matrix(S) - K), 0) * np.exp(-r*T)
lb_fix_put = np.maximum(np.mean(K - min_matrix(S)), 0) * np.exp(-r*T)
print(lb_fix_call, lb_fix_put)

def delta_model(model_name = None):
    price = tf.keras.layers.Input(shape = (1,))
    
    delta = tf.keras.layers.Dense(32, activation='tanh')(price_set)
    delta = tf.keras.layers.Dense(32, activation='tanh')(price)
    delta = tf.keras.layers.BatchNormalization()(delta)
    delta = tf.keras.layers.Dense(32, activation='leaky_relu')(delta)
    delta = tf.keras.layers.BatchNormalization()(delta)
    delta = tf.keras.layers.Dense(32, activation='leaky_relu')(delta)
    delta = tf.keras.layers.Dense(1, activation='relu')(delta)

    return tf.keras.Model(inputs=price, outputs=delta, name=model_name)

my_input = []

max_price = tf.keras.layers.Input(shape = (1, ), name = 'max_price')
premium = tf.keras.layers.Input(shape = (1, ), name = "premium")
hedge_cost = tf.keras.layers.Input(shape = (1, ), name = 'hedge_cost')
price = tf.keras.layers.Input(shape = (1, ), name = "price")
price_set = tf.keras.layers.Input(shape = (1, ), name = "price_set")

my_input += [max_price] + [premium] + [hedge_cost] + [price]

for j in range(N):
    delta = delta_model()(price)
    new_price = tf.keras.layers.Input(shape = (1, ), name = 'S_' + str(j + 1))
    my_input = my_input + [new_price]

    price_inc = tf.keras.layers.Subtract(name = 'price_inc_' + str(j))([price, new_price])
    cost = tf.keras.layers.Multiply(name = "stock_" + str(j))([delta, price_inc])
    hedge_cost = tf.keras.layers.Add(name = 'cost_' + str(j))([hedge_cost, cost])
    info_set = tf.keras.layers.Concatenate()([price, new_price])
    price = new_price

payoff = tf.keras.layers.Lambda(lambda x : tf.math.maximum(x - K, 0))(max_price)
cum_cost = tf.keras.layers.Add(name = "hedge_cost_plus_payoff")([hedge_cost, payoff])
cum_cost = tf.keras.layers.Subtract(name = "cum_cost_minus_premium")([cum_cost, premium])

model = tf.keras.Model(inputs = my_input, outputs = cum_cost)

def max_matrix(S):
    maxvec_S = np.zeros([M, 1])
    for j in range(M):
        maxvec_S[j][0] = np.max(S[j][:])
    return maxvec_S

max = max_matrix(S)
max_price = max
premium =lb_fix_call * np.ones([M, 1])
cost = np.zeros([M, 1])
SS = [S[:, i].reshape(M, 1) for i in range(N + 1)]
x = [max_price] + [premium] + [cost] + [SS]
y = np.zeros([M,1])

model.compile(loss='mse', optimizer='adam')

hist = model.fit(x,y, batch_size=32, epochs=50, verbose=True, validation_split=0.2)

plt.plot(hist.history['loss'])
plt.show()
# Out:
# 0.04375600590598895 0.039942257101569206
# Epoch 1/50
# 50/50 [==============================] - 38s 135ms/step - loss: 9.3592e-04 - val_loss: 0.0010
# Epoch 2/50
# 50/50 [==============================] - 3s 63ms/step - loss: 6.5922e-04 - val_loss: 9.2687e-04
# Epoch 3/50
# 50/50 [==============================] - 3s 63ms/step - loss: 5.1326e-04 - val_loss: 7.4299e-04
# Epoch 4/50
# 50/50 [==============================] - 3s 63ms/step - loss: 4.6355e-04 - val_loss: 6.4324e-04
# Epoch 5/50
# 50/50 [==============================] - 3s 63ms/step - loss: 4.2648e-04 - val_loss: 5.8693e-04
# Epoch 6/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.8997e-04 - val_loss: 5.3882e-04
# Epoch 7/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.9722e-04 - val_loss: 5.3442e-04
# Epoch 8/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.8193e-04 - val_loss: 4.5175e-04
# Epoch 9/50
# 50/50 [==============================] - 3s 66ms/step - loss: 3.7940e-04 - val_loss: 4.3446e-04
# Epoch 10/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.6796e-04 - val_loss: 4.2006e-04
# Epoch 11/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.5996e-04 - val_loss: 3.9086e-04
# Epoch 12/50
# 50/50 [==============================] - 4s 80ms/step - loss: 3.5507e-04 - val_loss: 4.4936e-04
# Epoch 13/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8124e-04 - val_loss: 4.4666e-04
# Epoch 14/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.6605e-04 - val_loss: 4.7893e-04
# Epoch 15/50
# 50/50 [==============================] - 4s 73ms/step - loss: 3.8098e-04 - val_loss: 4.4718e-04
# Epoch 16/50
# 50/50 [==============================] - 4s 78ms/step - loss: 3.7283e-04 - val_loss: 4.7454e-04
# Epoch 17/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.8117e-04 - val_loss: 5.1625e-04
# Epoch 18/50
# 50/50 [==============================] - 3s 64ms/step - loss: 3.6092e-04 - val_loss: 5.6158e-04
# Epoch 19/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.6138e-04 - val_loss: 5.0192e-04
# Epoch 20/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5369e-04 - val_loss: 4.3147e-04
# Epoch 21/50
# 50/50 [==============================] - 3s 65ms/step - loss: 3.3179e-04 - val_loss: 4.0114e-04
# Epoch 22/50
# 50/50 [==============================] - 3s 65ms/step - loss: 3.5448e-04 - val_loss: 4.2617e-04
# Epoch 23/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.4267e-04 - val_loss: 5.2741e-04
# Epoch 24/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.7962e-04 - val_loss: 5.1113e-04
# Epoch 25/50
# 50/50 [==============================] - 3s 65ms/step - loss: 3.4558e-04 - val_loss: 4.6997e-04
# Epoch 26/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.5837e-04 - val_loss: 4.6420e-04
# Epoch 27/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6955e-04 - val_loss: 5.3870e-04
# Epoch 28/50
# 50/50 [==============================] - 3s 66ms/step - loss: 3.5145e-04 - val_loss: 4.4825e-04
# Epoch 29/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.2534e-04 - val_loss: 5.2063e-04
# Epoch 30/50
# 50/50 [==============================] - 3s 64ms/step - loss: 3.4286e-04 - val_loss: 4.3352e-04
# Epoch 31/50
# 50/50 [==============================] - 3s 64ms/step - loss: 3.3545e-04 - val_loss: 4.8573e-04
# Epoch 32/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.3632e-04 - val_loss: 4.9801e-04
# Epoch 33/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.3132e-04 - val_loss: 4.1511e-04
# Epoch 34/50
# 50/50 [==============================] - 3s 65ms/step - loss: 3.3761e-04 - val_loss: 4.2412e-04
# Epoch 35/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.6710e-04 - val_loss: 4.1461e-04
# Epoch 36/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.3026e-04 - val_loss: 4.8278e-04
# Epoch 37/50
# 50/50 [==============================] - 3s 64ms/step - loss: 3.2646e-04 - val_loss: 4.9091e-04
# Epoch 38/50
# 50/50 [==============================] - 3s 64ms/step - loss: 3.3010e-04 - val_loss: 4.4234e-04
# Epoch 39/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.4029e-04 - val_loss: 4.3137e-04
# Epoch 40/50
# 50/50 [==============================] - 3s 65ms/step - loss: 3.4551e-04 - val_loss: 4.9159e-04
# Epoch 41/50
# 50/50 [==============================] - 3s 64ms/step - loss: 3.3788e-04 - val_loss: 4.3965e-04
# Epoch 42/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.4043e-04 - val_loss: 4.0046e-04
# Epoch 43/50
# 50/50 [==============================] - 3s 64ms/step - loss: 3.3363e-04 - val_loss: 4.4349e-04
# Epoch 44/50
# 50/50 [==============================] - 3s 64ms/step - loss: 3.4356e-04 - val_loss: 4.5018e-04
# Epoch 45/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.3457e-04 - val_loss: 3.9115e-04
# Epoch 46/50
# 50/50 [==============================] - 3s 63ms/step - loss: 3.2830e-04 - val_loss: 4.5502e-04
# Epoch 47/50
# 50/50 [==============================] - 3s 65ms/step - loss: 3.3954e-04 - val_loss: 4.4126e-04
# Epoch 48/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.4606e-04 - val_loss: 4.6046e-04
# Epoch 49/50
# 50/50 [==============================] - 3s 62ms/step - loss: 3.3833e-04 - val_loss: 4.5394e-04
# Epoch 50/50
# 50/50 [==============================] - 3s 65ms/step - loss: 3.2511e-04 - val_loss: 4.5983e-04

# %%
plt.hist(model.predict(x), bins = 30)
plt.show()
# Out:
# 63/63 [==============================] - 5s 19ms/step

# %%
plt.plot(S[:, -1], model.predict(x), marker = ".", linestyle = 'none')
plt.show()
# Out:
# 63/63 [==============================] - 1s 19ms/step
